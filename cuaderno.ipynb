# %%
import uuid
import pandas as pd

# %% [markdown]
# # Entidad y sector

# %%
entidades=pd.read_excel('./input/entidades.xlsx')
entidades.to_csv('./output/entidades.csv',index=False,sep='|',quotechar='"',escapechar="'")
entidades.head()
# Out:
#                                      id  \
# 0  0b4bb22e-1a88-4ce8-b69f-7ae4fba8a9d1
# 1  33af8b45-5729-4d4c-89da-46e4eccd9b42
# 2  81a5cc88-6183-427b-806c-1b2756fdd57d
# 3  1392a4b4-32de-4eac-9433-9c120e273b37
# 4  6e2f4e1e-b26e-497d-b6f0-bf30f162c1dc
#
#                                                 name  \
# 0                         Agencia Analítica De Datos
# 1  Agencia Distrital Para La Educación Superior, ...
# 2                                    Aguas De Bogotá
# 3                   Alcaldía Local De Antonio Nariño
# 4                   Alcaldía Local De Barrios Unidos
#
#                                          description  \
# 0  Entidad especializada en el análisis de datos ...
# 1  Organismo encargado de promover la educación s...
# 2  Empresa prestadora de servicios de aseo y gest...
# 3  Administración local encargada de la gestión y...
# 4  Entidad gubernamental responsable de la admini...
#
#                                               mision  \
# 0  Impulsar la toma de decisiones basadas en dato...
# 1  Consolidar el sistema de educación y formación...
# 2  En Aguas de Bogotá S.A. E.S.P. prestamos servi...
# 3  La Secretaría Distrital de Gobierno lidera la ...
# 4  La Secretaría Distrital de Gobierno lidera la ...
#
#                                               vision  \
# 0  Ser la agencia analítica de datos referente de...
# 1  En 2028, Bogotá será reconocida como una ciuda...
# 2  Aguas de Bogotá S.A. E.S.P., en el 2030, será ...
# 3  En el 2024 la Secretaría Distrital de Gobierno...
# 4  En el 2024 la Secretaría Distrital de Gobierno...
#
#                               sector_id
# 0  f61b45bb-c83d-4ea2-87f6-4a17dc92cd02
# 1  c97bc52c-238a-4e6c-b578-cc937e782e24
# 2  80e2d264-ef18-4b3a-be5a-17c5e5ecb982
# 3  4a3cbb2b-b651-4b09-8553-bc2de4be7d95
# 4  4a3cbb2b-b651-4b09-8553-bc2de4be7d95

# %%
sectors=pd.read_excel('./input/sectores.xlsx')
sectors.to_csv('./output/sectores.csv',index=False,sep='|',quotechar='"',escapechar="'")

# %% [markdown]
# # Respuestas

# %%
resp_19=pd.read_excel('./input/resp_2019.xlsx')
resp_21=pd.read_excel('./input/resp_2021.xlsx')
resp_23=pd.read_excel('./input/resp_2023.xlsx')

# %%
resp_19.head()
resp_19.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                   --------------  -----
#  0   entidad                                                                                                                                                                                                                                                                                                  40 non-null     object
#  1   1. Desde su creación hasta el 31 de diciembre de 2017, ¿existen acuerdos y/o actos administrativos de su entidad relacionados con el concepto de innovación pública?                                                                                                                                     39 non-null     object
#  2   1. Justifique su respuesta.                                                                                                                                                                                                                                                                              32 non-null     object
#  3   2. ¿Existen dentro de la planeación estratégica de la entidad enfoques / líneas / componentes / proyectos / programas o planes en 2017 relacionados con el concepto de innovación pública?                                                                                                               39 non-null     object
#  4   2. Justifique su respuesta.                                                                                                                                                                                                                                                                              33 non-null     object
#  5   3. ¿Cuál fue el valor del presupuesto de funcionamiento ejecutado a 31 de diciembre de 2017?                                                                                                                                                                                                             40 non-null     float64
#  6   4. ¿Cuál fue el valor del presupuesto de funcionamiento ejecutado en temas de innovación pública a 31 de diciembre de 2017?                                                                                                                                                                              39 non-null     object
#  7   5. ¿Cuál fue el valor del presupuesto de inversión ejecutado a 31 de diciembre de 2017?                                                                                                                                                                                                                  40 non-null     float64
#  8   6. ¿Cuál fue el valor del presupuesto de inversión ejecutado en temas de innovación pública a 31 de diciembre de 2017?                                                                                                                                                                                   40 non-null     float64
#  9   7. ¿Cuál fue le número total de funcionarios que trabajaron en su entidad en 2017?                                                                                                                                                                                                                       40 non-null     float64
#  10  8. ¿Cuál fue le número total de funcionarios que trabajaron en su entidad en 2017 relacionados con temas de innovación pública?                                                                                                                                                                          39 non-null     float64
#  11  9. ¿Cuál fue el número total de contratistas que trabajaron en su entidad en 2017?                                                                                                                                                                                                                       39 non-null     float64
#  12  10. ¿Cuál fue el número total de contratistas que trabajaron en su entidad en 2017 dedicados a temas de innovación pública?                                                                                                                                                                              40 non-null     float64
#  13  11. A partir de la información recolectada a través de "Bogotá te Escucha" (SDQS) en 2017 relacionada con su entidad, ¿su entidad realizó en 2017 alguna de las siguientes actividades? Seleccione las que apliquen.                                                                                     39 non-null     object
#  14  11. CONSOLIDADO A partir de la información recolectada a través de "Bogotá te Escucha" (SDQS) en 2017 relacionada con su entidad, ¿su entidad realizó en 2017 alguna de las siguientes actividades? Seleccione las que apliquen.                                                                         39 non-null     object
#  15  ¿Eligió la(s) opción(es) A, B y/u Otra?                                                                                                                                                                                                                                                                  39 non-null     object
#  16  12. En 2017, ¿su entidad contaba con canales complementarios a "Bogotá te escucha" (SDQS) para que la ciudadanía pudiera identificar retos o áreas de oportunidad de su entidad?                                                                                                                         39 non-null     object
#  17  Describa brevemente los canales complementarios que su entidad utilizó en 2017 para que la ciudadanía pudiera identificar retos o áreas de oportunidad de su entidad.                                                                                                                                    33 non-null     object
#  18  13. En 2017, ¿su entidad utilizó algún canal para que los funcionarios y/o contratistas pudieran identificar retos o áreas de oportunidad de la entidad?                                                                                                                                                 39 non-null     object
#  19  Describa brevemente los canales que su entidad utilizó en 2017 para que los funcionarios y/o contratistas pudieran identificar retos o áreas de oportunidad de su entidad.                                                                                                                               30 non-null     object
#  20  13.1 A partir de la información recolectada mediante los canales con funcionarios y/o contratistas para la identificación de retos o áreas de oportunidad, ¿su entidad realizó en 2017 alguna de las siguientes actividades? Seleccione las que apliquen.                                                30 non-null     object
#  21  ¿Eligió la(s) opción(es) A, B, C y/u Otra?                                                                                                                                                                                                                                                               30 non-null     object
#  22  14. En 2017, ¿se llevó a cabo algún(os) tipo(s) de actividad(es) para la identificación de retos o áreas de oportunidad de la entidad que usted representa? Seleccione todas las que apliquen.                                                                                                           39 non-null     object
#  23  ¿Eligió la(s) opción(es) A, B y/o C?                                                                                                                                                                                                                                                                     39 non-null     object
#  24  15. En 2017, ¿su entidad utilizó algún canal para la recepción de ideas de la ciudadanía, encaminadas al mejoramiento de su entidad?                                                                                                                                                                     39 non-null     object
#  25  Describa brevemente los canales que su entidad utilizó en 2017 para la recepción de ideas de la ciudadanía encaminadas al mejoramiento de la entidad.                                                                                                                                                    32 non-null     object
#  26  15.1 A partir de la información recolectada mediante los canales ciudadanos para la recepción de ideas relacionadas con el mejoramiento de su entidad, ¿su entidad realizó en 2017 alguna de las siguientes actividades? Seleccione las que apliquen.                                                    39 non-null     object
#  27  ¿Eligió la(s) opción(es) A y/o B?                                                                                                                                                                                                                                                                        32 non-null     object
#  28  16. En 2017, ¿su entidad utilizó algún canal para la recepción de ideas de funcionarios y/o contratistas relacionadas con el mejoramiento de su entidad?                                                                                                                                                 39 non-null     object
#  29  Describa brevemente los canales que su entidad utilizó en 2017 para la recepción de ideas de funcionarios y/o contratistas encaminadas al mejoramiento de la entidad.                                                                                                                                    29 non-null     object
#  30  16.1 A partir de la información recolectada mediante los canales con funcionarios y/o contratistas para la recepción de ideas relacionadas con el mejoramiento de su entidad, ¿su entidad realizó en 2017 alguna de las siguientes actividades? Seleccione las que apliquen.                             39 non-null     object
#  31  ¿Eligió la(s) opción(es) A y/o B?.1                                                                                                                                                                                                                                                                      29 non-null     object
#  32  17. En 2017, ¿su entidad realizó alguna actividad para la generación de ideas encaminadas al mejoramiento de su entidad? Seleccione las que apliquen.                                                                                                                                                    39 non-null     object
#  33  ¿Eligió la(s) opción(es) A, B y/o C?.1                                                                                                                                                                                                                                                                   39 non-null     object
#  34  18. En 2017, ¿su entidad diseñó innovaciones encaminadas al cumplimiento de los objetivos y metas de su entidad?                                                                                                                                                                                         39 non-null     object
#  35  18.1 ¿Cuántas innovaciones diseñó su entidad en 2017?                                                                                                                                                                                                                                                    41 non-null     object
#  36  Describa brevemente las innovaciones diseñadas.                                                                                                                                                                                                                                                          33 non-null     object
#  37  18.2 ¿De dónde surgieron las innovaciones diseñadas por su entidad en 2017? [A. Ciudadanía.]                                                                                                                                                                                                             34 non-null     object
#  38  18.2 ¿De dónde surgieron las innovaciones diseñadas por su entidad en 2017? [B. Funcionarios y/o contratistas.]                                                                                                                                                                                          34 non-null     object
#  39  18.2 ¿De dónde surgieron las innovaciones diseñadas por su entidad en 2017? [C. Exclusivamente del nivel directivo de la entidad.]                                                                                                                                                                       34 non-null     object
#  40  18.2 ¿De dónde surgieron las innovaciones diseñadas por su entidad en 2017? [D. Ejercicios de co-creación entre ciudadanía y funcionarios y/o contratistas]                                                                                                                                              34 non-null     object
#  41  18.3 Durante 2017, ¿se desarrolló algún prototipo de las innovaciones diseñadas?                                                                                                                                                                                                                         34 non-null     object
#  42  18.4. Durante 2017, ¿cuántas de las innovaciones diseñadas contaron o cuentan con un prototipo?                                                                                                                                                                                                          27 non-null     float64
#  43  18.5 Teniendo en cuenta los prototipos de las innovaciones diseñadas, ¿con quién se validaron el (los) prototipo(s)?  [A. Con los usuarios de la innovación. ]                                                                                                                                           27 non-null     object
#  44  18.5 Teniendo en cuenta los prototipos de las innovaciones diseñadas, ¿con quién se validaron el (los) prototipo(s)?  [B. Sin los usuarios de la innovación. ]                                                                                                                                           27 non-null     object
#  45  18.5 Teniendo en cuenta los prototipos de las innovaciones diseñadas, ¿con quién se validaron el (los) prototipo(s)?  [C. El prototipo no se validó. ]                                                                                                                                                   27 non-null     object
#  46  19. En 2017, ¿qué actividades relacionadas con la generación de capacidades de innovación desarrolló su entidad con funcionarios y/o contratistas? Seleccione las que apliquen.                                                                                                                          39 non-null     object
#  47  ¿Eligió la(s) opción(es) A, B y/u Otra?.1                                                                                                                                                                                                                                                                39 non-null     object
#  48  20. ¿Alguna de las innovaciones diseñadas en 2017 fue implementada, o está en proceso de implementación actualmente?                                                                                                                                                                                     39 non-null     object
#  49  20.1 ¿Cuántas innovaciones fueron implementadas o están en proceso de implementación?                                                                                                                                                                                                                    40 non-null     object
#  50  Describa brevemente las innovaciones implementadas en 2017.                                                                                                                                                                                                                                              32 non-null     object
#  51  20.2 De las innovaciones implementadas o en proceso de implementación, ¿cuántas fueron validadas con los usuarios?                                                                                                                                                                                       40 non-null     object
#  52  21. En 2017, ¿cuántos funcionarios recibieron formación en temas de innovación?                                                                                                                                                                                                                          40 non-null     float64
#  53  22. En 2017, ¿cuántos contratistas recibieron formación en temas de innovación?                                                                                                                                                                                                                          41 non-null     float64
#  54  23. Desde su creación hasta el 31 de diciembre de 2017, ¿existen acuerdos y/o actos administrativos de su entidad relacionados con la gestión del conocimiento?                                                                                                                                          39 non-null     object
#  55  23. Justifique su respuesta.                                                                                                                                                                                                                                                                             32 non-null     object
#  56  24. ¿Existen dentro de la planeación estratégica de la entidad enfoques / líneas / componentes / proyectos / programas o planes en 2017 relacionados con la gestión del conocimiento?                                                                                                                    39 non-null     object
#  57  24. Justifique su respuesta.                                                                                                                                                                                                                                                                             30 non-null     object
#  58  25. En 2017, ¿su entidad hizo público algún documento relacionado con el proceso, o los resultados del proceso, de identificación de retos o áreas de oportunidad con la ciudadanía provenientes de los canales y/o actividades mencionados en las preguntas 11, 12 y 14?                                39 non-null     object
#  59  26. En 2017, ¿su entidad hizo público algún documento relacionado con el proceso, o los resultados del proceso, de identificación de retos o áreas de oportunidad con los funcionarios y/o contratistas de su entidad provenientes de los canales y/o actividades mencionados en las preguntas 13 y 14?  39 non-null     object
#  60  27. En 2017, ¿su entidad hizo público algún documento relacionado con el proceso, o los resultados del proceso, de la recepción y generación de ideas con la ciudadanía provenientes de los canales y/o actividades mencionados en las preguntas 15 y 17?                                                39 non-null     object
#  61  28. En 2017, ¿su entidad hizo público algún documento relacionado con el proceso, o los resultados del proceso, de la recepción y generación de ideas con los funcionarios y/o contratistas de su entidad provenientes de los canales y/o actividades mencionados en las preguntas 16 y 17?              39 non-null     object
#  62  29. En 2017, ¿su entidad desarrolló algún tipo de documento encaminado a identificar y sistematizar lecciones aprendidas y buenas prácticas sobre las acciones de innovación desarrolladas por su entidad?                                                                                               39 non-null     object
#  63  29.1 ¿Qué hace su entidad con el documento de lecciones aprendidas y buenas prácticas de innovación?                                                                                                                                                                                                     39 non-null     object
#  64  ¿Eligió la(s) opción(es) A, B, C, D y/u Otra?                                                                                                                                                                                                                                                            11 non-null     object
#  65  30.  En 2017, ¿su entidad desarrolló algún tipo de documento encaminado a identificar y sistematizar lecciones aprendidas y buenas prácticas sobre las acciones de su entidad?                                                                                                                           39 non-null     object
#  66  30.1 ¿Qué hace con el documento de lecciones aprendidas y buenas prácticas de su entidad?                                                                                                                                                                                                                39 non-null     object
#  67  ¿Eligió la(s) opción(es) A, B, C u Otra?                                                                                                                                                                                                                                                                 19 non-null     object
#  68  31. En 2017, ¿su entidad desarrolló algún documento o matriz para hacer monitoreo y seguimiento a las innovaciones implementadas?                                                                                                                                                                        39 non-null     object
#  69  Unnamed: 69                                                                                                                                                                                                                                                                                              3 non-null      object
#  70  Dirección de correo electrónico                                                                                                                                                                                                                                                                          3 non-null      object
# dtypes: float64(10), object(61)
# memory usage: 22.9+ KB

# %% [markdown]
# # Personas

# %%
persons = resp_23[['entidad', 'nombre_responde', 'dependencia_entidad', 'cargo_responde', 'correo_personal', 'correo_institucional', 'tel']].drop_duplicates().copy()

persons = persons.rename(columns={
        "nombre_responde": "name",
        "entidad": "entity",
        "dependencia_entidad": "area",
        "cargo_responde": "job_title",
        "correo_personal": "email_per",
        "correo_institucional": "email_ent",
        "tel": "phone"
    }).reset_index(drop=True)

persons["id"] = 0

# Perform the merge and rename the relevant columns
persons = persons.merge(
    entidades[['id', 'name']],  # Keep 'id' and 'name' from entidades
    left_on='entity',           # Matching entity name in persons
    right_on='name',            # Matching entity name in entidades
    how='left'
)

# Drop the redundant columns and rename the ones we want to keep
persons = persons.drop(columns=['name_y', 'id_x'])  # Drop 'name_y' and 'id_x'
persons = persons.rename(columns={'id_y': 'entity_id', 'name_x': 'name'})  # Rename columns as needed

persons["id"] = [uuid.uuid4() for _ in range(len(persons))]

persons = persons[['id', 'name', 'email_per', 'email_ent', 'phone', 'area', 'job_title', 'entity_id']].drop_duplicates().copy()

persons.to_csv('./output/persons.csv', index=False, sep='|', quotechar='"', escapechar="'")

# Check the final result
persons.head()
# Out:
#                                      id                            name  \
# 0  d6ac90e6-0b09-428b-a522-cc560ea0eb76           MARIA ANGELICA ANGULO
# 1  d2849765-fd29-49e6-aa30-6e62e7e2394d  Cristian Andres Torres Malambo
# 2  32db5e6d-92db-4111-84b2-5599a4866f20         Jacqueline Ortiz Moreno
# 3  b37818f7-449d-4f55-806f-d6eeebaf066f      Luis Felipe Giraldo Romero
# 4  10b56489-44a1-41fb-917a-97488f08e9db           Ruby H. Valenzuela Q.
#
#                    email_per                                  email_ent  \
# 0      angie1701an@gmail.com        angelica.paez@gobiernobogota.gov.co
# 1         juvencus@gmail.com     cristian.malambo@gobiernobogota.gov.co
# 2      jakiortiz89@gmail.com      jacqueline.ortiz@metrodebogota.gov.co
# 3         calidoxo@gmail.com  desarrolloinstitucional@subrenorte.gov.co
# 4  valenzuelar60@hotmail.com           rvalenzuela@serviciocivil.gov.co
#
#         phone                                               area  \
# 0  3144709831                                           DESPACHO
# 1  3232073505                                         Planeacion
# 2  3005479183                      Oficina Asesora de Planeación
# 3  3002168804           Oficina Asesora Desarrollo Institucional
# 4  3005703088  Subdirección de Planeación y Gestión de la Inf...
#
#                                        job_title  \
# 0                           PROFESIONAL DESPACHO
# 1              apoyo del equipo de participacion
# 2                                    Profesional
# 3  Jefe Oficina Asesora Desarrollo Institucional
# 4                      Profesional Especializado
#
#                               entity_id
# 0  35492fe1-7cc7-4e86-a18c-aa42d2e6469c
# 1  f1e3fb07-af80-40e9-b3ba-951392680ceb
# 2  a835f2e5-8516-4942-8526-44d7338480bc
# 3  da3ccecf-b7ad-46f2-a759-edd4533cd47c
# 4  7e1205f0-4cd8-4e39-80fd-7651266ddc5f

# %% [markdown]
# # Indices

# %%
data = {
    'id': [
        2019,
        2021,
        2023
        ],
    'description': [
        'El Índice de Innovación del 2019 contó con la participación de 39 entidades y generó la linea base del Distrito en innovación.',
        'El Índice de Innovación del 2019 contó con la participación de 68 entidades y añadió a todas las Alcaldías Locales',
        'El Índice de Innovación del 2019 contó con la participación de 69 entidades y amplió drásticamente la información al incorporar búcles con información descriptiva.',
    ]
    }
indices = pd.DataFrame(data)
indices.to_csv('./output/indices.csv',index=False,sep='|',quotechar='"',escapechar="'")

# %% [markdown]
# # Jerarquia

# %% [markdown]
# ## 19

# %%
j_2019=pd.read_excel('./input/pre_2019.xlsx')
j_2019['index_edition_id']='2019'
j_2019['weight']=0
j_2019['question_type']="0"

j_2019 = j_2019.drop(columns=['T'])




c_2019 = j_2019[['Componente','index_edition_id', 'weight']].drop_duplicates().copy()

c_2019 = c_2019.rename(columns={"Componente": "name"})
c_2019["id"] = [uuid.uuid4() for _ in range(len(c_2019))]

c_2019 = c_2019[['id', 'index_edition_id', 'name', 'weight']]



v_2019 = j_2019[['Componente', 'Variable', 'index_edition_id', 'weight']].drop_duplicates().copy()

v_2019 = v_2019.rename(columns={"Variable": "name"})
v_2019["id"] = [uuid.uuid4() for _ in range(len(v_2019))]

v_2019 = v_2019.merge(
    c_2019[['name', 'id']], 
    left_on='Componente', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'component_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Componente', 'name_y'])

v_2019 = v_2019[['id', 'index_edition_id', 'component_id', 'name', 'weight']]



i_2019 = j_2019[['Variable', 'Indicador', 'index_edition_id', 'weight']].drop_duplicates().copy()

i_2019 = i_2019.rename(columns={"Indicador": "name"})
i_2019["id"] = [uuid.uuid4() for _ in range(len(i_2019))]

i_2019 = i_2019.merge(
    v_2019[['name', 'id']], 
    left_on='Variable', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'variable_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Variable', 'name_y'])

i_2019 = i_2019[['id', 'index_edition_id', 'variable_id', 'name', 'weight']]



p_2019 = j_2019[['Indicador', 'Pregunta', 'index_edition_id', 'weight', 'question_type']].drop_duplicates().copy()

p_2019 = p_2019.rename(columns={"Pregunta": "name"})
p_2019["id"] = [uuid.uuid4() for _ in range(len(p_2019))]

p_2019 = p_2019.merge(
    i_2019[['name', 'id']], 
    left_on='Indicador', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'indicador_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Indicador', 'name_y'])

p_2019 = p_2019[['id', 'index_edition_id', 'indicador_id', 'name', 'weight', 'question_type']]

# %% [markdown]
# ## 21

# %%
j_2021=pd.read_excel('./input/pre_2021.xlsx')
j_2021['index_edition_id']='2021'
j_2021['weight']=0
j_2021['question_type']="0"

j_2021 = j_2021.drop(columns=['T'])




c_2021 = j_2021[['Componente','index_edition_id', 'weight']].drop_duplicates().copy()

c_2021 = c_2021.rename(columns={"Componente": "name"})
c_2021["id"] = [uuid.uuid4() for _ in range(len(c_2021))]

c_2021 = c_2021[['id', 'index_edition_id', 'name', 'weight']]



v_2021 = j_2021[['Componente', 'Variable', 'index_edition_id', 'weight']].drop_duplicates().copy()

v_2021 = v_2021.rename(columns={"Variable": "name"})
v_2021["id"] = [uuid.uuid4() for _ in range(len(v_2021))]

v_2021 = v_2021.merge(
    c_2021[['name', 'id']], 
    left_on='Componente', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'component_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Componente', 'name_y'])

v_2021 = v_2021[['id', 'index_edition_id', 'component_id', 'name', 'weight']]



i_2021 = j_2021[['Variable', 'Indicador', 'index_edition_id', 'weight']].drop_duplicates().copy()

i_2021 = i_2021.rename(columns={"Indicador": "name"})
i_2021["id"] = [uuid.uuid4() for _ in range(len(i_2021))]

i_2021 = i_2021.merge(
    v_2021[['name', 'id']], 
    left_on='Variable', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'variable_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Variable', 'name_y'])

i_2021 = i_2021[['id', 'index_edition_id', 'variable_id', 'name', 'weight']]



p_2021 = j_2021[['Indicador', 'Pregunta', 'index_edition_id', 'weight', 'question_type']].drop_duplicates().copy()

p_2021 = p_2021.rename(columns={"Pregunta": "name"})
p_2021["id"] = [uuid.uuid4() for _ in range(len(p_2021))]

p_2021 = p_2021.merge(
    i_2021[['name', 'id']], 
    left_on='Indicador', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'indicador_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Indicador', 'name_y'])

p_2021 = p_2021[['id', 'index_edition_id', 'indicador_id', 'name', 'weight', 'question_type']]

# %% [markdown]
# ## 23

# %%
j_2023=pd.read_excel('./input/pre_2023.xlsx')
j_2023['index_edition_id']='2023'
j_2023['weight']=0
j_2023['question_type']="0"

j_2023 = j_2023.drop(columns=['T'])




c_2023 = j_2023[['Componente','index_edition_id', 'weight']].drop_duplicates().copy()

c_2023 = c_2023.rename(columns={"Componente": "name"})
c_2023["id"] = [uuid.uuid4() for _ in range(len(c_2023))]

c_2023 = c_2023[['id', 'index_edition_id', 'name', 'weight']]



v_2023 = j_2023[['Componente', 'Variable', 'index_edition_id', 'weight']].drop_duplicates().copy()

v_2023 = v_2023.rename(columns={"Variable": "name"})
v_2023["id"] = [uuid.uuid4() for _ in range(len(v_2023))]

v_2023 = v_2023.merge(
    c_2023[['name', 'id']], 
    left_on='Componente', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'component_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Componente', 'name_y'])

v_2023 = v_2023[['id', 'index_edition_id', 'component_id', 'name', 'weight']]



i_2023 = j_2023[['Variable', 'Indicador', 'index_edition_id', 'weight']].drop_duplicates().copy()

i_2023 = i_2023.rename(columns={"Indicador": "name"})
i_2023["id"] = [uuid.uuid4() for _ in range(len(i_2023))]

i_2023 = i_2023.merge(
    v_2023[['name', 'id']], 
    left_on='Variable', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'variable_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Variable', 'name_y'])

i_2023 = i_2023[['id', 'index_edition_id', 'variable_id', 'name', 'weight']]



p_2023 = j_2023[['Indicador', 'Pregunta', 'index_edition_id', 'weight', 'question_type']].drop_duplicates().copy()

p_2023 = p_2023.rename(columns={"Pregunta": "name"})
p_2023["id"] = [uuid.uuid4() for _ in range(len(p_2023))]

p_2023 = p_2023.merge(
    i_2023[['name', 'id']], 
    left_on='Indicador', 
    right_on='name', 
    how='left'
).rename(columns={'id_y': 'indicador_id', 'name_x': 'name', 'id_x': 'id'}).drop(columns=['Indicador', 'name_y'])

p_2023 = p_2023[['id', 'index_edition_id', 'indicador_id', 'name', 'weight', 'question_type']]

# %% [markdown]
# ## Unificado

# %%
c=pd.concat([c_2019,c_2021,c_2023])

# %%
v=pd.concat([v_2019,v_2021,v_2023])

# %%
i=pd.concat([i_2019,i_2021,i_2023])

# %%
p=pd.concat([p_2019,p_2021,p_2023])

# %%
c.to_csv('./output/componentes.csv',index=False,sep='|',quotechar='"',escapechar="'")
v.to_csv('./output/variables.csv',index=False,sep='|',quotechar='"',escapechar="'")
i.to_csv('./output/indicadores.csv',index=False,sep='|',quotechar='"',escapechar="'")
p.to_csv('./output/preguntas.csv',index=False,sep='|',quotechar='"',escapechar="'")
